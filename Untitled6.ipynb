# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.by import By
import time

# %%
driver=webdriver.Chrome()
driver.maximize_window()

# %%
url="https://www.cars24.com/buy-used-car?sort=bestmatch&serveWarrantyCount=true&listingSource=ViewAllCars&storeCityId=2378"
elements=driver.get(url)
for k in range(20):
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(2)
    element=driver.find_elements(By.CLASS_NAME,"_2YB7p")

# %%
#year_brand_name_variant
element[0].find_element(By.CLASS_NAME,"_11dVb").text
# Out:
# '2012 Toyota Etios Liva G'

# %%
#KMS_fueltype_tramissiontype
element[5].find_element(By.CLASS_NAME,"_3J2G-").text
# Out:
# '11,144 KM\nDIESEL\nMANUAL'

# %%
#price
element[6].find_element(By.CLASS_NAME,"_3RL-I").text
# Out:
# '₹2.47 Lakh'

# %%
#emi
element[6].find_element(By.CLASS_NAME,"-EPGU").text
# Out:
# 'EMIs from ₹8,204/month'

# %%
#location
element[0].find_element(By.CLASS_NAME,"_3dGMY").text
# Out:
# 'Free Test Drive Today at Goregaon, Mumbai'

# %%
cars_data =[]
for cars in element:
    try:
        brand_name = cars.find_element(By.CLASS_NAME,"_11dVb").text
    except:
        brand_name = "NA"
    try:
        fuel_type = cars.find_element(By.CLASS_NAME,"_3J2G-").text
    except:
        fuel_type = "NA"
    try:
        price = cars.find_element(By.CLASS_NAME,"_3RL-I").text
    except:
        price = "NA"
    try:
        emi = cars.find_element(By.CLASS_NAME,"-EPGU").text
    except:
        emi = "NA"
    try:
        location=cars.find_element(By.CLASS_NAME,"_3dGMY").text
    except:
        location = "NA"
    
    cars_data.append({'name':brand_name,'fuel' : fuel_type,'prices' : price, 'emis' : emi, 'Locations' : location})

# %%
print(cars_data)
# Out:
# [{'name': '2012 Toyota Etios Liva G', 'fuel': '52,656 KM\nPETROL\nMANUAL', 'prices': '₹2.37 Lakh', 'emis': 'EMIs from ₹7,872/month', 'Locations': 'Free Test Drive Today at Goregaon, Mumbai'}, {'name': '2018 Tata TIGOR XZ PETROL', 'fuel': '94,586 KM\nPETROL\nMANUAL', 'prices': '₹4.20 Lakh', 'emis': 'EMIs from ₹8,211/month', 'Locations': 'Free Test Drive Today at Goregaon, Mumbai'}, {'name': '2018 Maruti Dzire VXI AMT', 'fuel': '51,852 KM\nPETROL\nAUTOMATIC', 'prices': '₹5.74 Lakh', 'emis': 'EMIs from ₹11,222/month', 'Locations': 'Free Test Drive Today at Goregaon, Mumbai'}, {'name': '2016 Hyundai Elite i20 ASTA 1.2 (O)', 'fuel': '27,261 KM\nPETROL\nMANUAL', 'prices': '₹5.43 Lakh', 'emis': 'EMIs from ₹10,616/month', 'Locations': 'Free Test Drive Today at Goregaon, Mumbai'}, {'name': '2019 Volkswagen Ameo COMFORTLINE 1.0L', 'fuel': '34,651 KM\nPETROL\nMANUAL', 'prices': '₹5.72 Lakh', 'emis': 'EMIs from ₹11,183/month', 'Locations': 'Free Test Drive Today at Seawood'}, {'name': '2014 Maruti Swift Dzire ZDI', 'fuel': '11,144 KM\nDIESEL\nMANUAL', 'prices': '₹6.13 Lakh', 'emis': 'EMIs from ₹16,143/month', 'Locations': 'Free Test Drive Today at Goregaon, Mumbai'}, {'name': '2012 Honda Brio V MT', 'fuel': '61,764 KM\nPETROL\nMANUAL', 'prices': '₹2.47 Lakh', 'emis': 'EMIs from ₹8,204/month', 'Locations': 'Free Test Drive Today at Goregaon, Mumbai'}, {'name': '2018 Honda WR-V 1.2L I-VTEC VX MT', 'fuel': '59,897 KM\nPETROL\nMANUAL', 'prices': '₹7.11 Lakh', 'emis': 'EMIs from ₹13,900/month', 'Locations': 'Free Test Drive Today at Goregaon, Mumbai'}, {'name': '2016 Hyundai Creta SX PLUS AT 1.6 PETROL', 'fuel': '83,626 KM\nPETROL\nAUTOMATIC', 'prices': '₹8.54 Lakh', 'emis': 'EMIs from ₹16,255/month', 'Locations': 'Free Test Drive Today at Goregaon, Mumbai'}, {'name': '2015 Hyundai Grand i10 ASTA AT 1.2 KAPPA VTVT', 'fuel': '62,072 KM\nPETROL\nAUTOMATIC', 'prices': '₹4.16 Lakh', 'emis': 'EMIs from ₹8,133/month', 'Locations': 'Free Test Drive Today at Mulund West, Mumbai'}, {'name': '2015 Hyundai Elite i20 SPORTZ 1.2 (O)', 'fuel': '51,020 KM\nPETROL\nMANUAL', 'prices': '₹4.86 Lakh', 'emis': 'EMIs from ₹9,501/month', 'Locations': 'Free Test Drive Today at Goregaon, Mumbai'}, {'name': '2016 Maruti Baleno DELTA DIESEL 1.3', 'fuel': '62,767 KM\nDIESEL\nMANUAL', 'prices': '₹5.57 Lakh', 'emis': 'EMIs from ₹10,889/month', 'Locations': 'Free Test Drive Today at Mulund West, Mumbai'}, {'name': '2018 Hyundai Grand i10 MAGNA 1.2 KAPPA VTVT', 'fuel': '32,749 KM\nCNG\nMANUAL', 'prices': '₹5.26 Lakh', 'emis': 'EMIs from ₹10,283/month', 'Locations': 'Free Test Drive Today at Goregaon, Mumbai'}, {'name': '2016 Honda Jazz 1.2L I-VTEC V', 'fuel': '36,158 KM\nPETROL\nMANUAL', 'prices': '₹4.20 Lakh', 'emis': 'EMIs from ₹8,211/month', 'Locations': 'Free Test Drive Today at Goregaon, Mumbai'}, {'name': '2016 Maruti Celerio ZXI AMT', 'fuel': '76,727 KM\nPETROL\nAUTOMATIC', 'prices': '₹4.05 Lakh', 'emis': 'EMIs from ₹7,918/month', 'Locations': 'Free Test Drive Today at Goregaon, Mumbai'}, {'name': '2017 Maruti Baleno ZETA PETROL 1.2', 'fuel': '40,995 KM\nPETROL\nMANUAL', 'prices': '₹5.79 Lakh', 'emis': 'EMIs from ₹11,320/month', 'Locations': 'Free Test Drive Today at Goregaon, Mumbai'}, {'name': '2016 Maruti Baleno DELTA PETROL 1.2', 'fuel': '59,679 KM\nPETROL\nMANUAL', 'prices': '₹4.99 Lakh', 'emis': 'EMIs from ₹9,756/month', 'Locations': 'Free Test Drive Today at Mulund West, Mumbai'}, {'name': '2019 Honda City 1.5L I-VTEC VX CVT', 'fuel': '54,705 KM\nPETROL\nAUTOMATIC', 'prices': '₹9.58 Lakh', 'emis': 'EMIs from ₹18,235/month', 'Locations': 'Free Test Drive Today at Goregaon, Mumbai'}, {'name': '2016 Hyundai Grand i10 SPORTZ 1.2 KAPPA VTVT', 'fuel': '59,893 KM\nPETROL\nMANUAL', 'prices': '₹3.72 Lakh', 'emis': 'EMIs from ₹7,273/month', 'Locations': 'Free Test Drive Today at Seawood'}, {'name': '2022 Tata TIGOR XZ PLUS CNG', 'fuel': '24,490 KM\nCNG\nMANUAL', 'prices': '₹7.89 Lakh', 'emis': 'EMIs from ₹15,425/month', 'Locations': 'Free Test Drive Today at Goregaon, Mu ...

# %%
len(cars_data)
# Out:
# 598
